# %% [markdown]
# # 04 - OSM City Data\n\nFetches OpenStreetMap data for DFW cities (Dallas, Arlington, Fort Worth, Denton)\nand bakes into world_data/osm/. Runs Python OSM fetch script.\n\n**Runtime: ~5 min**

# %%
# !bash scripts/colab/setup_colab.sh

# %%
import os, sys\nsys.path.insert(0, 'scripts/colab')\n\n# Run the OSM fetch script\nosm_script = 'scripts/fetch_osm_cities.py'\nif os.path.exists(osm_script):\n    !python {osm_script}\n    print('OSM data refreshed. Check world_data/osm/')\nelse:\n    print('fetch_osm_cities.py not found - skipping.')\n    print('This is normal if OSM data is already baked into the repo.')
