# %% [markdown]
# # 03 - Asset Pipeline\n\nBakes GLB imports (generates .import sidecars), validates model slots,\nand optionally runs texture atlas generation.\n\n**Runtime: ~10 min**

# %%
# !bash scripts/colab/setup_colab.sh

# %%
import sys\nsys.path.insert(0, 'scripts/colab')\nfrom godot_runner import GodotRunner\n\nrunner = GodotRunner(project_dir='CATSINO.CASINO/godot')

# %%
# Bake all GLB assets (generates .import sidecars)\nresult = runner.bake_glb_assets()\nprint(f'Success: {result.success}')\nprint(f'Duration: {result.duration_seconds:.0f}s')\nif result.errors:\n    print(f'Errors: {len(result.errors)}')\n    for e in result.errors[:10]:\n        print(f'  {e}')
